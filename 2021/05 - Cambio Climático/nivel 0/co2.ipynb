# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_style()
sns.set_theme()

# %%
data = pd.read_csv('annual-co-emissions-by-region.csv').rename(columns={'Annual CO2 emissions (zero filled)':'Emisiones'})
display(data)
# Out:
#             Entity Code  Year  Emisiones
# 0      Afghanistan  AFG  1750          0
# 1      Afghanistan  AFG  1751          0
# 2      Afghanistan  AFG  1752          0
# 3      Afghanistan  AFG  1753          0
# 4      Afghanistan  AFG  1754          0
# ...            ...  ...   ...        ...
# 64255     Zimbabwe  ZWE  2015   12170460
# 64256     Zimbabwe  ZWE  2016   10814761
# 64257     Zimbabwe  ZWE  2017   10246841
# 64258     Zimbabwe  ZWE  2018   11340575
# 64259     Zimbabwe  ZWE  2019   10374287
#
# [64260 rows x 4 columns]

# %%
anuales = data.groupby(by='Year').sum()
anuales['Emisiones'].plot(figsize=(12,8))
plt.ylabel('Emisiones CO2 (miles de millones de Toneladas)')
plt.xlabel('Año')
plt.title('Emisiones Mundiales de Carbono', size=20)
plt.savefig('int-co2.jpg')
plt.show()
