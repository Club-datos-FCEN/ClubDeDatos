# %%
import pandas as pd

data = pd.read_csv("GlobalTemperatures.csv")
display(data)
# Out:
#               dt  LandAverageTemperature  LandAverageTemperatureUncertainty  \
# 0     1750-01-01                   3.034                              3.574
# 1     1750-02-01                   3.083                              3.702
# 2     1750-03-01                   5.626                              3.076
# 3     1750-04-01                   8.490                              2.451
# 4     1750-05-01                  11.573                              2.072
# ...          ...                     ...                                ...
# 3187  2015-08-01                  14.755                              0.072
# 3188  2015-09-01                  12.999                              0.079
# 3189  2015-10-01                  10.801                              0.102
# 3190  2015-11-01                   7.433                              0.119
# 3191  2015-12-01                   5.518                              0.100
#
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_style()
data['dt_datetime'] = pd.to_datetime(data['dt'])
data['year'] = data['dt_datetime'].dt.year
filtrado = data[data['dt_datetime'].dt.year >= 1940]

# %%
filtrado.plot(x='dt_datetime', y='LandAverageTemperature')
# Out:
# <AxesSubplot:xlabel='dt_datetime'>

# %%
anuales = filtrado.groupby(by='year').mean()
display(anuales)
anuales.plot(y='LandAverageTemperature')
# Out:
#       LandAverageTemperature  LandAverageTemperatureUncertainty  \
# year
# 1940                8.764667                           0.231083
# 1941                8.768667                           0.227833
# 1942                8.728417                           0.229500
# 1943                8.755083                           0.226583
# 1944                8.845000                           0.225167
# ...                      ...                                ...
# 2011                9.516000                           0.082000
# 2012                9.507333                           0.083417
# 2013                9.606500                           0.097667
# 2014                9.570667                           0.090167
# 2015                9.831000                           0.092167
#
#       LandMaxTemperature  LandMaxTemperatureUncertainty  LandMinTemperature  \
# year
# 1940           14.579083                       0.234917            2.890333
# ...
