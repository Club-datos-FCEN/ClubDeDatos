# %%
import pandas as pd

data = pd.read_csv("https://raw.githubusercontent.com/Club-datos-FCEN/ClubDeDatos/main/02%20-%20Iris/iris.csv")
display(data)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
data.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
sns.boxplot(data=data, x='species', y="sepal_length")
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
#hola estoy editando
sns.histplot(data=data, x="petal_length", bins=20, hue="species")
plt.show()

# %%
sns.histplot(data=data, x="petal_width", bins=20, hue="species")
plt.show()

# %%
traduccion = {'petal_width': 'Ancho de Pétalo (cm)',
              'petal_length': 'Largo de Pétalo (cm)',
              'sepal_width': 'Ancho de Sépalo (cm)',
              'sepal_length': 'Largo de Sépalo (cm)'}

sns.histplot(data=data, x="petal_width", bins=20, hue="species")
plt.xlabel(traduccion['petal_width'])
plt.show()

# %%
grid = sns.pairplot(data, hue="species")
# plt.show()
print(grid.legend.get_texts())
# Out:
# <a list of 3 Text objects>

# %%
import seaborn as sns

sns.violinplot(data=data, x="species", y="sepal_length", hue="species",
               split=False, inner="quart", linewidth=1)

sns.despine(left=True)
plt.show()

# %%
species = data.species.unique().tolist()

color_map = {'setosa': 'royalblue', 'versicolor': 'darkorange', 'virginica': 'g'}
colors = data.species.map(color_map)


import matplotlib.patches as mpatches
handles = [mpatches.Patch(color=color_map[key], label=key) for key in color_map.keys()]

fig, ax = plt.subplots(3,3,sharex='col',sharey='row',figsize=(6*3,6*3))

traduccion = {'petal_width': 'Ancho de Pétalo (cm)',
              'petal_length': 'Largo de Pétalo (cm)',
              'sepal_width': 'Ancho de Sépalo (cm)',
              'sepal_length': 'Largo de Sépalo (cm)'}

for i in range(4):
    for j in range(i):
        x, y = data.iloc[:,j], data.iloc[:,i]
        ax[i-1,j].scatter(x, y, c=colors)
        ax[i-1,j].set_xlabel(traduccion[x.name])
        ax[i-1,j].set_ylabel(traduccion[y.name])

ax[0,2].legend(loc='center', handles=handles, labels=species, fontsize='x-large')
plt.show()
