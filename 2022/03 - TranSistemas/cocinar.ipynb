# %%
import pandas as pd

# %%
LABELS_BASE = './Labels/'
blacklist = [
    'Edad',
    'Total de Personas afrodescendientes',
    'Que Provincia Nació-Nombre'
]

def arreglar_nivel(data, nivel):
    variables = pd.read_csv(LABELS_BASE + f'{nivel}-VARIABLES.csv', sep=';', index_col='variable')
    columnas = variables.index.to_list()
    for columna in columnas:
        try:
            data[columna]
        except KeyError:
            continue

        nombre = variables.loc[columna]['label']
        data.rename(columns={columna: nombre}, inplace=True)
            
        if nombre in blacklist:
            continue
        
        try:
            valores = pd.read_csv(LABELS_BASE + f'{nivel}-{columna}-LABELS.CSV', sep=';', index_col=columna)
        except FileNotFoundError as e:
            print(f'Not found! {e.filename}')
            continue

        indices = valores.index.to_list()
        dicc = {indice: valores.loc[indice]['label'] for indice in indices}
        data[nombre] = data[nombre].map(dicc)

    return data

# %%
data = pd.read_csv('crudos.csv')

# Departamentos y Provincias

deptos = pd.read_csv('DPTO.csv', sep=';', index_col='DPTO')
provs = pd.read_csv('PROV.csv', sep=';', index_col='PROV')

depto_dicc = {depto: deptos.loc[depto]['NOMDPTO'].rstrip() for depto in deptos.index}
prov_dicc = {prov: provs.loc[prov]['NOMPROV'].rstrip() for prov in provs.index}

data['DPTO'] = data['DPTO'].map(depto_dicc)
data['PROV'] = data['PROV'].map(prov_dicc)


# Otras cosas

data = arreglar_nivel(data, 'VIVIENDA')
data = arreglar_nivel(data, 'HOGAR')
data = arreglar_nivel(data, 'PERSONA')

data
# Out:
# Not found! ./Labels/VIVIENDA-VIVIENDA_REF_ID-LABELS.CSV
# Not found! ./Labels/HOGAR-HOGAR_REF_ID-LABELS.CSV
# Not found! ./Labels/PERSONA-PERSONA_REF_ID-LABELS.CSV
#        Identifier for VIVIENDA Tipo de vivienda agrupado  \
# 0                      2353463                Particular
# 1                      2353463                Particular
# 2                      2353536                Particular
# 3                      2353577                Particular
# 4                      2353577                Particular
# ...                        ...                       ...
# 19325                    52305                Particular
# 19326                    52305                Particular
# 19327                    52305                Particular
# 19328                    52330                Particular
# 19329                    52330                Particular
#
#              Tipo de vivienda particular Area Urbano - Rural        DPTO  \
# 0                                   Casa              Urbano   Comuna 01
# 1                                   Casa              Urbano   Comuna 01
# 2                                   Casa              Urbano   Comuna 01
# 3                                   Casa              Urbano   Comuna 01
# 4                                   Casa              Urbano   Comuna 01
# ...                                  ...                 ...         ...
# 19325                               Casa              Urbano  Río Grande
# 19326                               Casa              Urbano  Río Grande
# 19327                               Casa              Urbano  Río Grande
# 19328  Pieza en hotel familiar o pensión              Urbano     Ushuaia
# 19329  Pieza en hotel familiar o pensión              Urbano     Ushuaia
#
#                                   PROV  Identifier for HOGAR  \
# 0      Ciudad Autónoma de Buenos Aires               2491115
# 1      Ciudad Autónoma de Buenos Aires               2491115
# 2      Ciudad Autónoma de Buenos Aires               2491190
# 3      Ciudad Autónoma de Buenos Aires               2491231
# 4      Ciudad Autónoma de Buenos Aires               2491231
# ...                                ...                   ...
# 19325                 Tierra del Fuego                 58740
# 19326                 Tierra del Fuego                 58740
# 19327                 Tierra del Fuego                 58740
# 19328                 Tierra del Fuego                 58768
# 19329                 Tierra del Fuego                 58768
#
#                         Tenencia de agua  \
# 0      Por cañeria dentro de la vivienda
# 1      Por cañeria dentro de la vivienda
# 2      Por cañeria dentro de la vivienda
# 3      Por cañeria dentro de la vivienda
# 4      Por cañeria dentro de la vivienda
# ...                                  ...
# 19325  Por cañeria dentro de la vivienda
# 19326  Por cañeria dentro de la vivienda
# 19327  Por cañeria dentro de la vivienda
# 19328  Por cañeria dentro de la vivienda
# 19329  Por cañeria dentro de la vivienda
#
#       Procedencia del agua para beber y cocinar Tiene baño / letrina  ...  \
# 0                                   Red pública                   Sí  ...
# 1                                   Red pública                   Sí  ...
# 2                                   Red pública                   Sí  ...
# 3                                   Red pública                   Sí  ...
# 4                                   Red pública                   Sí  ...
# ...                                         ...                  ...  ...
# 19325                               Red pública                   Sí  ...
# 19326                               Red pública                   Sí  ...
# 19327                               Red pública                   Sí  ...
# 19328                               Red pública                   Sí  ...
# 19329                               Red pública                   Sí  ...
#
#               Categoría ocupacional Le descuentan para jubilación  \
# 0                     NOTAPPLICABLE                 NOTAPPLICABLE
# 1                     NOTAPPLICABLE                 NOTAPPLICABLE
# 2                 Obrero o empleado                            Si
# 3                 Obrero o empleado                            Si
# 4                 Obrero o empleado                            Si
# ...                             ...                           ...
# 19325             Obrero o empleado                            Si
# 19326                 NOTAPPLICABLE                 NOTAPPLICABLE
# 19327                 NOTAPPLICABLE                 NOTAPPLICABLE
# 19328  Trabajador por cuenta propia                 NOTAPPLICABLE
# 19329                 NOTAPPLICABLE                 NOTAPPLICABLE
#
#       Aporta para jubilación Afrodescendiente  Indígena  \
# 0              NOTAPPLICABLE               No        No
# 1              NOTAPPLICABLE               No        No
# 2              NOTAPPLICABLE               No        No
# 3              NOTAPPLICABLE               No        No
# 4              NOTAPPLICABLE               No        No
# ...                      ...              ...       ...
# 19325          NOTAPPLICABLE               No        No
# 19326          NOTAPPLICABLE               No        No
# 19327          NOTAPPLICABLE               No        No
# 19328                     No               No        No
# 19329          NOTAPPLICABLE               No        No
#
#       Máximo Nivel de Instrucción  Que Provincia Nació-Nombre  \
# 0             Secundario completo                          34
# 1             Secundario completo                          34
# 2             Secundario completo                          54
# 3             Secundario completo                          54
# 4             Secundario completo                          38
# ...                           ...                         ...
# 19325      Universtiario completo                         100
# 19326         Primario Incompleto                           2
# 19327    Universitario incompleto                           2
# 19328         Secundario completo                         100
# 19329       Secundario incompleto                           2
#
#       Condición de actividad tipo de dificultades o limitaciones permanentes  \
# 0                   Inactivo                                   NOTAPPLICABLE
# 1                   Inactivo                                   NOTAPPLICABLE
# 2                    Ocupado                                   NOTAPPLICABLE
# 3                    Ocupado                                          Visual
# 4                    Ocupado                                          Visual
# ...                      ...                                             ...
# 19325                Ocupado                                   NOTAPPLICABLE
# 19326          NOTAPPLICABLE                                   NOTAPPLICABLE
# 19327               Inactivo                                   NOTAPPLICABLE
# 19328                Ocupado                                          Visual
# 19329               Inactivo                                          Visual
#
#       IX_TOT
# 0          2
# 1          2
# 2          1
# 3          3
# 4          3
# ...      ...
# 19325      4
# 19326      4
# 19327      4
# 19328      2
# 19329      2
#
# [19330 rows x 38 columns]

# %%
data.to_csv('cocinado.csv')
